# %% [markdown]
# Dataset Link:
#
# https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Upload csv file and then read the contents

df = pd.read_csv("/content/features_30_sec.csv")
df.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
# Output Column = label
# Remove Columns = filename, length

# Try visualizing correlations of the features

# %%
df.shape
# Out:
# (1000, 60)

# %%
df.drop(['filename', 'length'], axis=1, inplace=True)
df.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.350088         0.088757  0.130228  0.002827
# 1          0.340914         0.094980  0.095948  0.002373
# 2          0.363637         0.085275  0.175570  0.002746
# 3          0.404785         0.093999  0.141093  0.006346
# 4          0.308526         0.087841  0.091529  0.002303
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1784.165850          129774.064525              2002.449060
# 1             1530.176679          375850.073649              2039.036516
# 2             1552.811865          156467.643368              1747.702312
# 3             1070.106615          184355.942417              1596.412872
# 4             1835.004266          343399.939274              1748.172116
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 0            85882.761315   3805.839606  9.015054e+05  ...   52.420910
# ...

# %%
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])
df.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.350088         0.088757  0.130228  0.002827
# 1          0.340914         0.094980  0.095948  0.002373
# 2          0.363637         0.085275  0.175570  0.002746
# 3          0.404785         0.093999  0.141093  0.006346
# 4          0.308526         0.087841  0.091529  0.002303
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1784.165850          129774.064525              2002.449060
# 1             1530.176679          375850.073649              2039.036516
# 2             1552.811865          156467.643368              1747.702312
# 3             1070.106615          184355.942417              1596.412872
# 4             1835.004266          343399.939274              1748.172116
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 0            85882.761315   3805.839606  9.015054e+05  ...   52.420910
# ...

# %%
df.dtypes
# Out:
# chroma_stft_mean           float64
# chroma_stft_var            float64
# rms_mean                   float64
# rms_var                    float64
# spectral_centroid_mean     float64
# spectral_centroid_var      float64
# spectral_bandwidth_mean    float64
# spectral_bandwidth_var     float64
# rolloff_mean               float64
# rolloff_var                float64
# zero_crossing_rate_mean    float64
# zero_crossing_rate_var     float64
# harmony_mean               float64
# harmony_var                float64
# perceptr_mean              float64
# perceptr_var               float64
# tempo                      float64
# mfcc1_mean                 float64
# mfcc1_var                  float64
# mfcc2_mean                 float64
# mfcc2_var                  float64
# mfcc3_mean                 float64
# mfcc3_var                  float64
# mfcc4_mean                 float64
# mfcc4_var                  float64
# mfcc5_mean                 float64
# mfcc5_var                  float64
# ...

# %%
mask = np.triu(np.ones_like(df.corr(), dtype=np.int64))
sns.heatmap(df.corr(), mask=mask, cmap="YlGnBu")
plt.show()

# %%
X = df.drop(['label'], axis=1)
y = df['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Using Multi-class SVM Classsifier with one-vs-Rest Approach

# %%
svc_ovr = SVC(decision_function_shape='ovr')
svc_ovr.fit(X_train, y_train)
y_pred = svc_ovr.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.20666666666666667

# %% [markdown]
# Feature Scaling using Standard Scaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Using Scaled Features for Multi-class SVM Classifier with Over-vs-Rest Approach

# %%
svc_ovr_scaled = SVC(decision_function_shape='ovr')
svc_ovr_scaled.fit(X_train_scaled, y_train)
y_pred = svc_ovr_scaled.predict(X_test_scaled)
accuracy_score(y_test, y_pred)
# Out:
# 0.69

# %% [markdown]
# Using Decision Trees Classifier on Scaled Features

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train_scaled, y_train)
y_pred = dtree.predict(X_test_scaled)
accuracy_score(y_test, y_pred)
# Out:
# 0.4666666666666667

# %% [markdown]
# Using Random Forest Classifier on Scaled Features

# %%
rforest = RandomForestClassifier()
rforest.fit(X_train_scaled, y_train)
y_pred = rforest.predict(X_test_scaled)
accuracy_score(y_test, y_pred)
# Out:
# 0.6666666666666666

# %% [markdown]
# Using Logistic Regression

# %%
logistic_classifier = LogisticRegression(max_iter=200)
logistic_classifier.fit(X_train_scaled, y_train)
logistic_predictions = logistic_classifier.predict(X_test_scaled)
accuracy_score(y_test, logistic_predictions)
# Out:
# 0.6933333333333334

# %% [markdown]
# Using KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
pred = knn.predict(X_test_scaled)
accuracy_score(y_test, pred)
# Out:
# 0.6533333333333333
